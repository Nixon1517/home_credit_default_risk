# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from bokeh.plotting import figure, output_file, show

# %%
train_df =  pd.read_csv( "C://Users//chris//.kaggle//competitions//home-credit-default-risk//application_train.csv")

# %%
test_df = pd.read_csv("C://Users//chris//.kaggle//competitions//home-credit-default-risk//application_test.csv")

# %%
train = train_df

# %%
#encode AMT_INCOME_TOTAL
train['AMT_INCOME_TOTAL'] = pd.qcut(x=train['AMT_INCOME_TOTAL'], q=12)

# %%
sns.barplot(x='AMT_INCOME_TOTAL', y='TARGET', data=train)
plt.show()
sns.barplot(x='FLAG_OWN_CAR', y='TARGET', data=train)
plt.show()
sns.barplot(x='NAME_CONTRACT_TYPE', y='TARGET', data=train )
plt.show()
